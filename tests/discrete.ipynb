# %%
from NPMLE.parameters.discrete_normal_parameters import Discrete_Normal
from NPMLE.utils.NPMLE_util import OLS
import numpy as np

# %%
model = Discrete_Normal(lg=np.linspace(-1.5, 1.5, 70))
data_geneartor = model.generate(1000)

# %%
theta, X, y = next(data_geneartor)

# %%
w = model.NPMLE(X, eta=0.01, verbose=True)
# Out:
# iteration 0: loss=2.6039, gnorm=0.1646546
# iteration 50: loss=2.6030, gnorm=0.0000194

# %%
# %matplotlib widget
model.plot_heat_prior(w)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pmX = model.calculate_post_mean(X, w)

# %%
OLS(y, pmX)
# Out:
# array([ 0.0079647 , -0.00706714])

# %%
model.beta
# Out:
# array([ 0.2, -0.1])
