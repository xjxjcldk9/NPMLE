# %%
import matlab.engine
import matplotlib.pyplot as plt
import numpy as np

# %%
eng = matlab.engine.start_matlab()
s = eng.genpath('/home/r10323001/Dual-ALM-for-NPMLE')
eng.addpath(s, nargout=0)
eng.addpath('.', nargout=0)

# %%
# d=2
# 跑之前的OTP NPMLE試試看，用正確的OLS

def npchecker(B, n):
    for i in range(B):
        yield eng.matlab_wrapper(n, nargout=3)

# %%
b, grid_m, w_m = next(npchecker(2, 10000))

# %%
b
# Out:
# matlab.double([[0.9890305456480283],[2.010525964108311]])

# %%
grid = np.array(grid_m).reshape(-1)
w = np.array(w_m).reshape(-1)

# %%
plt.scatter(x=grid, y=np.cumsum(w))
